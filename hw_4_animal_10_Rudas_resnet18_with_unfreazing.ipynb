# %%
# conection to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# unziping dataset
# !unzip /content/drive/MyDrive/data/Animals-10.zip -d /content/dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/raw-img/ragno/OIP-MVQChNQpHiMZEVMPehrvoAHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MVdIFDAFpNyK_XCpwkDIWgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MYY_8k5AHqMJwTCNXfH6rwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MZEVXuoMsATG8u_UuTQ6hAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MZg0tznDRE95AMfyuutuYAHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-M_r9DkR2X5gP0P5-z8wPYQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-M_xDUSzjlF3-w9XHCm93cgHaFF.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MbI4-bMyutRX3X382IAVcQAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MbMksZdD7gomsC9fd6cpKgHaHJ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Md4AMcvjaHcivJqeW06wEwHaFW.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MgCgailkT5XkO1XczzQCngHaLK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MgrKq05YHGXsgj1AmYIyJQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MhRGx7d8nbnHBuqrsO00EQHaFo.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MiVgMXcKGQdog2KGe7i0YQHaHh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Mis0lJf3Xbf3ulUg4DQ_EwHaFz.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Mj15wALS_srxPktt6trhhQHaGA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Mj_JhYslbL_Xbj5lBBziagHaFb.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MktEsZ9eQtFDPLU71DNOAwHaEh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ml7Od1dGkqkJgXpJDpC0dQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MmB9gn8-sdjLQTpPv6ik3AEsDw.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MmoKpEIgWJOoQZux8LtrcgHaGd.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Mnup5kCuX4fDtL-4c1nPBAHaFG.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MoHsdM75gQrv0NYl1aifewAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MobhPjsXyp_M_L7aVfjBTgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MpWY8USoo7z6Ul6gsox6hwHaFB.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MqT6ows3Vfujxhn1ZsILLwHaH3.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MrXUjxU63G5QvlSA7POglQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Mtuf-Z8wzpHtqJcsPKwcSwHaEu.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MulCmOLsjloKVs0XdUMIBgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-MvMHzibGqWz0Q1jYREh19QHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Mx1w4PgwBd-68Me2CDRzcAHaH1.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N-tPWHoqfyfq29tGIuLc3gHaFc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N1DWiJWqIdTYCi_mTu1WSgHgGq.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N1VRShGh0nyoABHiGtkgBwHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N1_ydMiJVUapYjVp9VleGQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N4QnS18z97J8yyGAWT6SugHaEg.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N4yVFeTWUWJkiP3anfBHXgHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N5mhpEWK5y4jp2HjhH_K3wHaG6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N80qtlHn6PEipw_dfV9jOAHaGP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N9pNu0AMQ6deVjo_dPzjJAHaGV.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N9sV_xOZMvz4WFnk3HQ5pwHaFT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NAGGGb3SK4b5YyDzce40ewHaFy.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NBgPlOD0msNGZCmOmr_rTQHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NDJS-cBWgvkqjt7k2QrtsAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NDRIGl44ve6C2eZNMUqedgHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NDbZ47jDW29d8_5Te5MmfQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NEz3tGremP_ji3zQWUY2rgHaFt.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NFF363mrNJ2nE-Hu5-rq5wHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NFjaSFfls2ykxtBEIkjfIwHaFa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NG-YoGbDU3z8d48uwtAeSgHaFf.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NHePijjozJTd0b3z-QGxygHaLH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NJ5rwMWeXPi-kY_1y78KrgHaHT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NK6G6DaN1dRZ8pE1SPVtfAHaFk.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NKHFl8gEWgf-QQO8KMGvSAHaGl.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NKJXhMo0G_pLhekfFVzX3QHaEn.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NKdSg2RRt6TUYnPEDwHIRgHaGa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NKxgfGuSX9dGvLHG0J1pygHaFw.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NL5R7iirMmPal_81BaPfhQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NMmYV_eIIrlmv_fgNzzkAAHaEh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NNntiXFRT7b1PX6HxiIqPAHaGP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NNs8QplJkorWckbGKh7QJgHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NOKWtTVQjfoNKr77412r3gHaFF.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NQCZaBwUeO976CDeerdLtAHaJ4.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NQtOKlzWz1LIEexsPRrXQwHaFV.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NSz21xFCfkOCEFSE79_lxAAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NTWIInYr-vxFETcAYoeEhgHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NTdhhbLgoVkxoUtgof1smQHaEi.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NTkcdPTkrDGyrMR9J0hLVAHaFW.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NTs0KEc27pk79sPgwm_k8AHaGR.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NTw9yNW5kExrHEdfA02bYwHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NUyp81k6QRIUWMpbfVktRAHaG9.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NVEzEp7x5pzM9BemLYdyAQHaFf.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NVQ2DaXTMofaZS3I92pjagHaGj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NYIgh0FElpEwA4s6VlNKdgHaEy.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NZhJPlSwsQMgwLc2vyZOBgAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N_PSOugSg3Me2hvsgNaoZQHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-N_j1s3uSXURo5MoaqiFR4gHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NaYU1TUE-Bw37ZSw8fqnUgHaF7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NbVgiZSNAww7vUK7trG5egHaFW.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Nc4-khftdrZPUS3XrgZ6aAHaF8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NdgwnW6ZQodrhbTsDmrL2gHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ne8H87YXxaXfIbC86CKpugHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NeLs9COJaa55-61TVswLfwHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Nim-ssakfJ5YWzH20pW6OAHaEK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NjJEOX2FWhxKPMnFW6MqggHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NjtO4MN4R2W0VSOFfFKvOQHaGy.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NmBKsv9wDMXsQfQ_svIf9gHaFm.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Nm_V_V2SQrXIYpwwnkwQ3gHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NmihfkmrZD3AblmVmnNyRwHaJ4.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NnAAmAHdDOsdfnso0TxooAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NnVy1MMOvLcdwr2KoN9lRgHaIH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NoyzkSk0ZL4SVxUGLdEKgQEsDd.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Np-D6yApeWdfnTdiCfxVHwHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NpPcbXU4SNIZsjwZUaj0RAHaJt.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Nqut8S-lwtAN_JXafmsLeAHaJA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NrvRKpy_RPgUWECudCk0_AHaHQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ns4JB5uKeeP95mruVHlXzAHaEC.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NsiVrQQ3x6GynX4N1o3CKAAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NsnTSp4y3bGyXJH2NFKVawEsC-.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NsuKI9-tvnxmXe2m-wuX5QHaJ_.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NwDqne1H_DuxIG5EYWnYkQHaFv.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ny6-6zue0hfqJwSqZFncqQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-NyGoX3F4x7_jFPEtNhb5_QHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O2SUhoexJgAT4tHFqntgGQHaG6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O2ZqQdmez-I_Yf7mk3YJ4AHaHg.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O3QQUy1rW6ddI8e8ysT_8AHaEL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O3gAIBhn15gCfRtk-9cSSQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O50QKwXnDXa44j3_CjtJkgHaHj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O6226QLF98skMDgLXzf9IQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O7FVRC6nzJm94M7Tjbm7sAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O8pS0Olk1otgzutk3t9AMAHaF0.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O8ro-ygCQE-PzCMzs2Fc7AHaEY.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-O9z9zxCsOhpT3gNcuVLtAAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OAUhHTgSEUtmZwIz9BcCSQHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OBmNP1EbjyYEhd8K1_ll1wHaFs.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OD-LVdbKDuHQFC5OPezyTwHaIN.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OFrnDZP_biqIx74M-9m5ygHaFL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OGGhZdRSPoBDkiFFD2XuigHaHA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OGZmv0Z0G015zRM2UKK9IAHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OHd-Xpm5BGKXM7ECMPjq8QHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OHxdksMs6mDPjGi9wIc8PwHaGB.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OIKkxsMR-kWg3G0wtTsHwgHaGM.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OIQkH8OzEm2VGqngEYCX6QHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OJGel7mdTGSIMRF8CtwR2QHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OJINzf4MB7iwX_EhD7tZ2AD5D5.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OLgqBkqAu879TNm2UiJGBAAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OMCZnF9poWMitOgOUh0suQHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OMjDhRzKvUg2NcaJZ3DwTQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-ONzNPD-FvC7lUxkk3yM1BQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OOF_3P4vmRsXmeyNHFQ4-wHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OOY7Uo--av2V1IpGpu8yHQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OOhImS56BmFaXoGNrCb6HwHaIn.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OQkV42kPr4dADopolvElPAHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OQrBWChh5B0aM-hnFAGfiAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OQrQech2Fjo7JgJyZfTmiAHaFK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OReTIh1Tz1D5OnscQPnsIgHaGL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OS4L0V9YQvPlZEupXh7shwHaDY.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OT7pMnLp2CwzG2HoxKjXIgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OVqUPVGD1ErEeasmRPT1PAHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OVur9SZc2mOXdBIzyoLniQHaFk.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OXNwuHlwUVopvVMLjEeE3ADjEs.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OYdK9EXC8qd6xGSsDUDVbgHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OZW3nY9x1JHiwli2Pa9z7gHaFG.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OZq9urwdQ7KjjzdHM3XNCQHaFk.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Oah_NcxDPBObP38IpQekJgHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-ObBeU01CowwFA8stRy_fggHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-ObSZXVI1eF-1AyKl97BDAwHaFJ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-ObwwMQQHcLTisT85AGqKNAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OdbybRkXkQ6PYz4IeoBH_wHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OfrkGVHkrskVS1I4a1A5agHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OgFBQkuCcIT5MoYYHrCsqgHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ogt5Yd8OuitnziQ1Zjc-uwHaJY.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OhrgL5EVqyIu0hXQisuufQHaIw.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Oi97_p0gYb0OFNH7k6dJWwHaFs.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OiwrCSUxe3nlGjD7EYXA6QHaLG.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OjAGGJK9HNU0cnjx8buPzAHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OkNLhataJD8FpFJziqcMlAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OlOll0vtiXyeMaKlZ6SZZwEsDH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Oni7pNS4zWzu8XC78hwaSwHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OoDT-oN-R1MHE75lH_QhjwHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Or2uaBluxaRym-X9eV6XaAEsDG.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OuIvIhJToMRhS_f_HC-hwQHaFQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OumwuK3UQxJH7jr6F1os-QHaJV.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ouo3gjagVK3GZVsYrQ_WTQAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-OuwrXXQ8MKuEFKlBOP10nQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P-FZlXPehsfoX1ZY7_I1xgHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P0P0pVhyUjEVtbw2Zlb-ZgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P2J6ReKV854wb_IP_oQA7QHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P3A_n_R-upozrUVwN00t2wHaFg.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P3KhNtyIRUDCjfke2P4H1AEsDw.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P3gSEkn73iN7Kkt_TItUiAHaEu.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P5nhbSH6u0fhH5l-od7vKQAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P6zhEiAopCUUAhYSTLcTbAHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P8ts8T0J5pZLnsKQJWRvzAHaDm.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P9peuhi0y6eKQ6jsRfmOfgHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PA4ov7X9qiCgyTmJyNQmnQAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PAF698yO9AWmUISBmI5B5wHaFc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PAGRuC7D44Ddmc9c4NcIRAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PBM6Zxen4xbXttXv56WwOAHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PBl1NmqtKOS0jJacu-q5rwHaJc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PBpY2VUkcZmk17DqdXdfGwHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PD24gj1TBUPL_ZGwykBCVAHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PFfEzR-yINyw0moB6r7NGQHaGU.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PFsL-KNZKPdvoJkyhbnIZAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PHgD7f9-QxOf3tOA240cKwHaFx.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PJTAhUYRD72V-n_wHeeNpQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PLCOe4GBbSpg2G4WXoe5lQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PMUAhcHKPOhLDtYc5xRcGgHaFr.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PNF_-7_RxeT89k9Iq25VSAHaEK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-POOYRTYyIqvsEPv2_gmGsgHaHe.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PORM-RxUfuU-FF-SK6xS6gHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PQ8KZ9wNl4cWBGQojJ1-6QEsDh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PQgtCHsA1XD0FQOyku5zPwHaE4.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PRoYCqijybWr_J2OuZ46oAHaF1.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PRslYUUnlZgW78GAa5J1FQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PRtPq0GUeUkcTBIDeZ10SAHaFc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PSLnzQU2XD16XFPvI0-ZFQHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PSmWcuOqnhp7KGK7jehnMAAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PStpj5oD1w87I6u-k8EFVAHaFx.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PT-W2ptAgfEEOXXVOueizwHaGD.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PTLYkgK9huVpqvRW0eADVwEgDY.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PU-BeFCd7dkyTjH8tjSjgwHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PUeOlqvtsJgFrU7TEjcq0QHaHC.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PV9C90aANeTBV4pmRUNpDAHaFC.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PWieXTxJhj01r_1tYNUChAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PXF7yhBIAIlPl8d7jsivhwHaHQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PZ0tbgHuIeEh2rLFaCcR3QHaFy.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PZbMmXxz46gqHtg91hAptwHaIc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P_EXUxl8-5P_hgnUbZUQsgHaFy.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-P_R-dGwRouknGRnrdVZs6gHaEL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PbGSyZ0ZLqpOFyeZqY7JwAHaGr.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PdGwmM0tUThLkXi5w9EJCQHaLH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PdU3qT0EktKCf4T2oI1BiQHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PdhkAW0EpslON9I7jckNvwHaGK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PdmQgC6PllU7zc3LF8rOpwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PeMKgcR5jq5W92mqDb_UrAHaLJ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PgdI_Jn9HMoE7sLz1rZpKAHaG6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Phh-Yj0bpf6hC0eb3PoIGQHaFA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PjtuvhWIg1aNMkBBtxboyAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PlqQ16JMCuP8SLpV2l3_AwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Pn0xj7GZaRlkxKuKZO0F2AHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Pn7ltn4yjBjjaVodMrqFqQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PnI7iQICpA1tfEOL1G2d3wHaG8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PnfHmBI8Jq9AAsVhBGlSTQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PnlKhmT0qMjNrK7yWFpRwQHaLI.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Pp4JSMm_qOp5uF1sHfOtpAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PqUR-LAYRIEUI3PXPBZ3XgD7D4.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PqwbmQfvVwX7BGz4Iv3FBgAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Pqyoalx-CmFx8DcKuxstigHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PsTfOcc74Puw4wtsI_JwtwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PswEohrjwTIabvSezg6LiQHaGv.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PtHjNZGxK0CYwqFXXb4vQgHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Pu6dMSU81BaPg3O9NnpE5wHaFE.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PusHDiIcu99ZXMzx8KJd_gEsDh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PwQz0kurwsFie-tTDXIYeQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PwfvYAPiA-IvvAXJstAFNAHaGI.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PyODQWk5eLntFJDggvDLUQAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PyeNjq2YAOW6ZGRGrXJqGAHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PyuYkdLyMKjYXxctTiREbwDZEf.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-PzPmhq7OWH4BREpL_UDXBAHaFP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Q-CCNK3jp7BZ-_XoMAsW2wHaFz.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Q-NVpDKdpd3md_Ok14dH7AEsEY.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Q0LPu5gg-ANHCb666ph_3gHaEw.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Q2uC4pz8shAh7njh3n6NqAAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Q45gbDG5bSlbI3TdL9ZQTgHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Q5KbeDCCznekgmJIFoQytAHaFP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QB-o7O7XItf0ett6s1nn8gHaFl.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QB84VuW390iQUe3EH_8hGgHaFO.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QCHOnriD3QfYtXr6s6rY-gHaHl.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QD1zmOjnLTbT1QSA2ysgPwHaKA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QEE5NeuhKlzLsyJeq_nKPwHaDt.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QEYXEYHeR2hsuyOXPfly5QHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QEpdeNIQL0C6eoEIaTAJ2wHaF0.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QFpiwc_WQt0lFuZbNIGZAQHaFw.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QGSuAXz57tqBK-18Fjmd1wHaF7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QGgNgciREO0FGNAhydsvNQHaJQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QGsCvgQEnocUE0BDXEN3RwHaF6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QGyeICsYYeiqMcdXDL3vtAHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QHLEjUB_MzCBxnoU0KSFqwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QJNVASYG4lBobxk4SjLYPwHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QKZq0b7RhZCpHS8ghW-elAHaE9.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QKv_Y5CtSFu78XOS0Df8VgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QMZ7V6HMZjlGZYvEUa9KXQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QP7a-b5AFtkqBW0WrFDk_AHaHT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QPGaWC94hxgKm5GKO4r2vQHaI7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QPJB2WqWzLfjiMPEAL874gHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QPyDrYtsBwPZstE_oAni5AHaF4.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QQTnNoz8ha5JPCfhU-a79AHaG8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QQqnj-hQZ6D30LYIKFsoBQHaFu.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QSKQmZFGXNsRxhk_W6fRFQHaFV.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QSdt2QX5Zo7uSoNKlVcYdQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QSxtk2wF7oZsq6vTwbj3bAHaFw.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QTgJUDxkWMdF1O9f_oIiVgHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QUCCFSvJLbXXr2pAEu4ZQgHaEK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QVYWA5PHP02Dy-XSzl6jiAHaFd.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QVk4c8D1_-y6NxVCN40DlQHaE1.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QdKjZxBL_qR7qTLzWtLhnwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QdxKWfm-BBjL0dLCiEchVgHaHO.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QfW44SKTvRgln6eUH5cyVADmEs.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QfqZqpdA_pDzsqJVZysAcAHaFT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Qhpuim9aXMAvr49T3un3IgHaFY.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QikUzm0cvZzNmuNl8Swt_gHaEd.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Qn8Zip8n_FRFNNfD_CSU7QHaFL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QncUE12SPde6FK08RNsyVQHaFa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QnpeVCHhj0GldUSLZu6BUwHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QoEMgkhbchMgVKKH4wEkWAHaFR.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QqnOKz5oUg0BO4GK3KdNSQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QrZDtkYlpz_dfmT_4x1yiAHaEt.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Qs58ZIwQ9tEoA8jdWHkwsQEsEd.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QtyMKUdioVaVREp28Pcb8QHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Qukr2unhCJpfRdGcrfjhLgHaFh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Qup5aKCXsd8Jp-ln-4emdQHaGR.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QvnxuY16ntwUmpnp27CyMQHaEL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QwWPdj5pa2z_n2ir6wxASwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QxNPzr1Tt0Jn4xm-a7KXKwHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-QyYmL6A4ytBTIKy5LctbgQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Qz8Dg-NLLTJv22ohJ3LDaQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R-bsUZJ9ZDij3zNQuKpZQgAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R2aXV1a712GIiCDzq3n2EgHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R2g4SIhpZ-TtkXx9E-bLIwHaFL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R3Xtfu1PCpoRmrZs_DBbzgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R3ickltemnx2xfEypB5F3AHaFr.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R4C6SSsaiyfQIRsGA4elhQHaLH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R5QNk5jGfbdSfmTQGb07CQHaIe.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R5TnRwWoZ9lPJjRwpptjAwHaGl.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R6CcakuTMeS6S8gicSK3ggHaLG.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R7qckJRDWOAEsPmU-84PnwHaIu.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R7woZPafZk84xXr8dVGuBwHaFq.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R8uvK0O6ifAzaYSMdUExywHaE9.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R8xu9BOLAu_W45CMfGf3HQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-R9x3DBd-vP4SWY3j5w4VKwHaFi.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RBmJq9zLjnr1sSK80kxoOAHaFb.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RCDWnbtFXFOYpBRTx46W_gHaGz.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RChaSbgSZ_Sgtq2ogP4kAgHaFR.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RCoyv14un4ZTq6ImJgaesAHaF6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-REWpVQMj2wqQ2yuJUoEZpwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RH-g3EnylBrfhqQr7-r_vgHaFz.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RHORrsSXo3njXvxqYef92QHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RJQfavMQKWokWMGTnxLmBAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RKucaaukSCOuBMhpvKkl1AHaF3.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RL-VH84r9Ap4mX4__Vx42gHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RN7Grd0X2QRprci7s6gf8QHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RNcRps2tt4pUxSkovkRSCwHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-ROxuqunQnIlc0DUpNPb_lwHaGP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RQsW8YMNu1zfmvjewCmEegHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RQx7vXtOawoGA5zUF1DAVQHaLJ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RTxGhYUTUqg2p3ctBQoOwwEsDI.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RUZhSWo-pLhX3ARYYEZ9fAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RWIuXB2LkxSKO9SKll9dqwHaEI.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RXhyISYUUvNTzVQl4vcD_QHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RYmertP_NJ2ppl3jqVumbQHaHg.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RZl4MrTdY6VNw3puA_AgTAHaH9.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RekVnxOex6EKg9-NHez6KAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RevqY_TkwRo-RGoEMT5JHgHaFT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RewchCB3gGq_IHDAICrlnwAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RfNVja5IJqaXxv1svI9f0QEsDJ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RgmrsYPrYrE3qClrSmvXoAHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RhDR3Xm3kPCTg-wN84Uv9AHaLJ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Rhse5kXTiP7V0uDl3qfapgHaGc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RiKQSKsak6CeO0s1pbGr8QHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Rk07MhzBxBjB0lZ34ZGnXQAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RlwYHDDCRwDj9ylCVpaIJwHaG2.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RoUlt1t6aK5Dqo896dPIPQHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RpvkpbRdk0lr4VWhi1UYNAHaG7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RqZBOZuBdklmXn39Io4wswHaF1.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RrCZnTYc6uwvSoauCt66PwHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RsVUVc9Lc5tliRNQCg4kPwHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RsoOv56vjNaHJcERlx21SwHaHv.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RtNDQzEdpGZn9uAdtRocNgHaIP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Rv9YSvm6P4XQkYCVsZwWqAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RvjgJxquttNRglG_r0i_PwEsDw.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Rw3oXeu15B0uH3n7M7gIlgHaFq.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RxjIlEcFGjtgAktQl7oN2AHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RyBGZuOEeZNn6o8tbEwTVwHaFi.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RyhrpsqORyBlYaJDjeNNSQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RzZnv0vNHnvCM0BuoxG2nwHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Rzf0Ek7IoNCSKybmjUhj8gHaE5.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-RzuyGgXxORH7iL8UfXML3wHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S13WNX__0c-AbU1M11hcwgHaF2.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S2DlENRcYRnN8waay8P2qgHaLG.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S2EXoTc5HlxAgnCSG42h6QHaFi.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S54J7RQK0hqVjmRlNVDb_gHaGD.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S6Pk9_AKwcUhAWDt6gcRtAHaFt.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S6cMPe-Ov4UbKRg4kzsgMQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S6djJaVEBioLqJgkn9HLAwHaDi.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S7kjT2mko0PkpJDiquW33AHaIb.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S7nN9zHQaGg8LoU3OoD8SgHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S7tKog7Wzzbv4BCzZRxU-gHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S9wF5WjcTZNTHkXwj7Az_QHaHN.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SA6_HRRSXQBCGIHRtF3i_AHaFL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SAAJtpu_56ASJEzV4gGMTgHaFN.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SB96ZmHROJPdMJryxgDgQwHaE0.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SDEwJDQoaMFRTrH1NYL7ngHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SDyO6sifakJM1Twmt0W47wHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SF6Gp8GTAn1H3hxNdjHN-AHaF9.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SHSnNXpHiJbKw5OWlFVXkgHaE_.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SHb2BRjhPOXGWkzpYhhweAHaFE.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SHrw0yEPPmDWr6LaOzGYZAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SIUt8A1tjKifQpv1CtMInwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SJPb_ikAqZGs7IZeIheX4wHaIT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SL0B690kQ_ehfUe7JRyVCgEsDI.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SLqiJpHHhi-Ft_b7UUCovAHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SLt6HAfc3iRXfS2DxKFhrgHaE1.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SMRXkWBWPHwztpFghdB26QAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SPZS2HOxgoY_i6JlY5bINQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SPg7-Z1tULEItxuDpc8W9QHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SPx0POO4f51gfLh44TcGJwHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SQGtymyosmHfzXJ423sySgHaIW.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SQSKe0JQ-KDjsmFLd_9ccwHaFA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SQz5pFcGhIRchAhHqOUbygHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-STRqEjCRzbEt6p0vAtDrpwHaJQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SUCRFmmO6N6Z7RAmCKfvPwHaHR.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SUMrKWxBzTAEHc4t7qwYNgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SUx1DIcR-asaW0ivY8fJ1wHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SVy_l-07r_8nLw9pB9wKUAHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SWDYgp3tI2T7Qr5_rcNNEAHaGh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SWjYhAhITa-eR8AMFE4fUwEsDl.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SXB9vSpWgbWfLNqFPweuMgHaJQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SY0AoGdDpYcAOAnVs3mgXwHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SYXHBygSLa9aKmngHz819QHaJC.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SYexOpCRhipAg7tqbCBZcAHaLH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SZBfgtar5m2xT3Vl3EN6lAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SZXpQ3UFQTHK13ZjE65zTAHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-S_mXP_UjxFfWMGehaeAh9wHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SdaQuiDTDOjRdSTOCYyVCgAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SeP24jITiXU8pq3aqmmg6gHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SerWzXmqcu_D52JnthkVzQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SfxEClVREkuzNGvRjRc81QHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SjqZo0COW5ItN-J9awyJHQHaGs.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Sjw-w2ZWdIati1gCmX2cSgHaJx.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Sjz2GnNuwrFrYsiTVMZMmgHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SmZjMLnWd7_cnPDXsKWq_gHaFY.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SnhcZWACk4pUAas7B63PFwHaFV.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SoJdd7qo7w1cP8m33fjKlQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SrSI6zM1T7kjK5YwSGNXMAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-StYd_RTxu0Y6DYCw49ZvpwHaFK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SvLd5ROxhLJSwnAHUi3OegHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Svth6v-e_LxRqyujVvfDnwHaHg.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-SxczmgATqwjZ31byls0lDAHaFP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-T0DuGcnWuwdfSVQkTpDKvgHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-T18YH45BXzMZyShXE_KSIQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-T1odt0DysqybU07BO2tv8gHaFh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-T6iUl1R893Ygeh6K1H_kbwHaGQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-T6qc_VtP6VSpgDg8l08QUwHaF7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-T8y9k2Ey0VfdwfieM2y2JgEsDg.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TAHAcPy-yYXE2IVyLtP4SAHaEi.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TBCTEYofwj88GpOknUHuuAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TC5St9ZLq8L2N1pGolLYRwHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TCwhjrgcR6d6aLNBl_30gwHaF0.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TDSav1hwdeTp1tBcv87VRAHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TDkeDOWHi7eebTbgLNMBZwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TE_Z4E_1d7Xg8SJZuu8lgAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TGlC7x-RyaPOIMJkwzmhGwHaLH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TJHqKeL0nM_3Lk_JJUMRbgEGEs.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TJIP64zGL53f5BcqIw8bCgHaLh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TJvzvG3tEhbLYxY1927SvQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TKigr0z3RqLCk1hh1A4miAHZHg.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TKzTSpBjAr47lmyf9CKamAHaF5.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TMHRl7LMVT_bxrf7z1itzQHaLB.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TOhFim3lDiX0JiRkuQMKOwEsEb.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TPOL_y2MfpCtbWA9xVAgmAHaFT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TPdIIP6rqZMTVzNhAthr-AHaHg.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TPzvkDZkc4MGw_6rf7WcYQHaGT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TRVYxpsuc4ZwAX146HIXnAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TRjxSbM7QpJZR9afQaHX5AHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TSqAP-DT_CMN3w6K4B1IkQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TUKtFdgZ3Zf5_WHRKss-cQHaFT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TV07-lJghBd5TDvanS9qowHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TV2FFMxlN9sZraS6Vhj7NAHaJZ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TWnJDX5W1ZCE9locQiYdpgHaG0.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TWvnB-w0gV4M-aYmIbQ70gHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TXU4xKiwwNfyvGdvaIIdKgHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TYQWZpRN51eofy4fUpZ39wHaGK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-T_SpLEgbzKoPMkS78y_HLwHaFL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-T_qoYyFRCP3vE5rtIGnCrwAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ta4EK5VKkka_4yq5Tr_s6AHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TaRVzvNkCQmZQQchvly9LgHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TcSE6XcbMCn07C50J_w6HQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TeUmCMeP7BBubLnBnLUhcQHaF7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TfoVSwETeRQF86rH-77a9QHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TgXxCOAUvdk-lA0O-llkdgHaD8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TksaIVV_sh-hV9tbNW2OTgHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Tl9mIcVFNjrDFkhv0c0ALwHaL2.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TlsbOMIhrVJWLlhq3kEkLwHaEK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TmhA4P9KfG_I_jyI2p46wgHaF8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TnAIPqnQ9qQAbq0v0vVFwwHaFo.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TnUd3m0Z6kgVfx2PxEYFjAHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TpmGPXmW6eQgN2Mfltoi3gHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TrvRRwaofqr7h_YvezJetgHaE-.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TsAlRhj57bLLWKMaPsdhxwHaHH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TsCQ0Nmqo2OFGolbgJaQdwEsEU.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TsR7nB6VRtB0Kv5ZOYO18AHaHX.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TsTd9m0iusClQEOL-L6doQHaF1.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Tu6db40mJ3vwV12I5yzDLgHaFk.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TucUistkkPWzuZ-ftCIC4AHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TyBzMo3Tg2AXwgzGhwsF0gAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-TzAXrRIS-kBbDsbjsPptoAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U-E1ut5UI8O9TDcPQixDsgHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U0dqvcWCXPYM8fXdkSVEmQHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U0m8CixqS0ZmV8x3PHcy5wHaEK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U3BC_akr9SZCOBzTbMDy9wHaFN.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U3RfcADrPojJhgDDXco3sAHaFn.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U3vmu-20VgHbz5eEIh-lAgHaFT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U5uifwFqr02osWh7MAY5tgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U7AkGhKxfMovMbRDwDHm-wHaF5.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U7_91V1pc3YNLn7_P6XhmgHaGO.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U895PVAJG6QWznNiCMjAiQHaG0.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U8a2Qv9Z34EYwD-_9L9PdgHaHi.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U9f5d9-fhtXVo3erxresdAHaJ4.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UAb2QXLU4Zq8wQVMQHN5DgHaFQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UAf6yyDWk5mIwxILpqmVbAHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UB0mB8bK4rhLhu8ckbVa_QHaFP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UC4dV6Yt0dibWBIqKclXeAHaFr.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UCjOqmRzIoBU-Rgwr7mbJAHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UFEoc9zV3OcK9PoZbu9r0AHaFC.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UGRqfL8ZLFmpMQfzOiD-twHaFK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UIVg6O4Vfsdxrto2KYbxcwAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UJ1Qid-dMsT6fKtJe36_yAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UKJ36N7YdPe0-JU6btzQqAHaGD.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-ULLRx5hzpo24JqkbAnzpEwHaFc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-ULsAkvFUQrOEGCZd-YvWXAHaDY.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UOQfpsZzqxfUCY5ikpGUpgHaLF.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UOjMsHdhBO6yFhsn-SJXIgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UQsaXXg6E05twXAV4dfobAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UR8a1gizXV3doT5gFKGsTgHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-URhkIP5bRihFvPytG1SIGQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-USo36UnL8BeQKvFoUsmcjAHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UURZR8z6e5y_ZTO372Q_AQHaFt.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UUmls8RiIQDknQFkFrprgQHaCd.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UVUL4KFQFCFhIk_EkRaLkgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UVZomHpJdomCy5VQ2-B06AHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UWbLla0JyQmH-b_fGtnd7AHaFN.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UWiebwKp2UeZSdlAsXW17gHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UWsO4pGoG-sTCyAqjPnwdQHaGv.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UXkO2nyIPtDNj2Nxzg_3ygAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UYIz6imCGoJbagBg96c77wHaFM.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UZkt8v_kRXeMxGMv1JB5LwHaHQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UZl4c6nKJcQjXt6nhTlizwHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-U_H346yNnzIcKHLYzUHT4QHaGc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UalacnC_5R7JXTuL_sJGcgAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UbMCFAirOpIiyYhVK1id9AHaFo.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ue1EdEa0Z_rmqf9LxJhV8wHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UeF4V_y-5nGFljich6lf0wHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UfxjPgQMOcfGAvz7tF-PmQHaE6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UgWirsye8cPWKRReZaHivQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UgaZOKOUI-pmxtggxWJfcgHaGb.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UgqBdeizvpolo-grP3WQ-AAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Uh37C1ePBbQjKOW5cKWm_gHaLD.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UhF-rMdzamQi6DOpYp2sPwHaFp.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UidAZK5yIvVD1RlJLmr-iQHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UjMiQQoVJABAcHstiW8L0AAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Uk9jVHuzqKqwl34DqD6K2AHaFq.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UkPZSdmiRJoQwhxmZqN85gHaF0.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UkuPCUjVhzrrMGrqnG2vdgHaE9.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UlHpZK37HCEYULkSVLAFegAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UmIFlGhR12x_p2pdPyP3zgHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UnklUgF8Qx_7tzcUxgQBrAHaF7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Uo7t_kFSjWzfxUTa-VGuWgHaE9.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UoTN8fKDcP_p2vr3AhhwcQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Upi7Jtev92rv7rr0BnxUbAAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Ups1_0QOi3FonkBnas_dAwAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UqlVs_4mgNvF-r9GMonvFAHaMb.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UqquXHcWGYo6Kb8f9K62EAHaJQ.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UrTX8myfCgmaCsiMRmsaNgHaLh.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UrxH_gwcsHRZjgzHkJ_XVgHaFK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UsKm2WrWkR4zkzJOjueGUAAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UsrvLFIG1ktdhVO9MCxiqwHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UufDQQEoneOrJZReFwsqTgHaHH.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UvLLJP-iOQP-dJP8p1nIsQHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Uz6TULYuTesV3LJz-QJR4QHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-Uz78mxju3aJEpAnjZMoA0QHaFS.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-UzxfkKkYu_VJW_YXXJrlDwHaH2.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V-RuXDD2fLD294LXCbaYvQAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V-Whb_Od5Tfp5GjzC0VoWQAAAA.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V-cdkyrRQr-JpDZstWX13QHaE9.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V00xqRWXb6HaSmNxO5ZYyAHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V0t4KmWwOQkXwMDOm9jNqAHaEs.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V1D522RaSRwEKIwh2uoEUAHgFu.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V1oztA3N0Wm_QGFBvW988QHaLf.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V2Vp5dqvQ42jKiVVVfKFLAHaFo.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V37vmFyaAUoUzm1GqfBXfQHaE5.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V4w-NFBPJgYnP80IWbyC-wHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V6LgtBjZb6dshuECCt_rYAHaGK.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V6pFNoCJQFEJPP0-3-ychQHaG_.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-V8WpsRhFjGZoqlelgs4CmwHaFP.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VAHSDuZDAEG-mZh5-sqvTAHaE8.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VBjgq841wQ0WuK2x7z4yQwHaFz.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VD8uJc0C39FzCs9h2DVJKQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VDgfKLdf1RwIACSxVdP2zQHaG5.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VE7-fTEKigfw56Vdf5UytgHaFr.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VJRDX-Jq70Mj0dli1jfh_AHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VJY2zsTrbhRagV2bXoIVNQHaGc.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VKIaSxbQSybMzGWBzr9SYwHaJ4.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VLCQ36MxRmIwbBF1SNMHPgHaF0.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VLMEOQKLxfTOHw99v4XnGgHaE-.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VMehxQV3JCZXTvZzz3FrmwHaFj.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VMfIo6twe610F9NxWHB3XQHaE7.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VPfbm-6jUnz8VGojTcjFIQHaFT.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VQ3h4JiVdqYxjJJ6p1gOIwHaG6.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VSbvHxtRLp-Q060vuTx3vQHaE-.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VSzTAiASrq9nl6xD7Zd9XwHaHa.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VUFWlkxifg-i1OWP-iAxvAHaHf.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VV8_bfxg_vBaOjUH4dpACgHaFL.jpeg
#   inflating: /content/dataset/raw-img/ragno/OIP-VVbsWFcGcQd-qaUHkrkyjwHaE8.jpeg
# ...
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uJB9pRIrSeaXmgOhGWWJEQHaFi.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uK5S01BFg2VkupcfWXncOgHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uKQngjJ7GV4GQ2zUDIOIgwAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uNWoWgwKRNS9I52B2XtcogHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uNePBa1FMePOOqdgm8iS9gHaHj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uOGrffgD9D9Urr9LRtbySwHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uONCENVWE7UmE-r7yk_-xQHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uTQvk4Idu2YOnNMc_XahOQHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uWI8fnWbp9rXwxa29AImvQHaMW.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uWkOctyY2lQ-_3fdmZEAGgHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uWuyTlAomjXpfTZfBjADLgHaFc.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uY5_QNIrjDPqpfSI-YZ2WgHaHL.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uZ0n3otW4uyRWBZMcX2XqAAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ugHvCfRkge3BVeRuC571AgHaKD.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uj6xzipAIHJHbXLBraw-6QHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ujXhO__7onTIrN_Rghx7iQHaGF.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-um4_xfqUsC8axBnXfvhdtgHaFi.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-umqR5SURfMT77gSmHcwOXwHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-umqniSZjV5pw0tx1PhdsIwHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-upQw2sJjRiSxJ9JIqonyXwHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-upfXMlRA-NcKAlcwfabxhgHaH1.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-utUn8wm35u54VZCq3CNZagHaFk.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-utdd6pCHL4E9tnjP2YMxUQHaGS.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uuIZcpts2YBinOZR-77vwQHaE9.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uw1eVwUgXCHiBkVA5yU-wwHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-uxv0A909Oo9rEjcdw5thBwHaFf.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-v7OfHmsFkufP7VqAz2B29QHaF7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-v7WqbiErldK7p-3OwDD9yAHaE3.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-v9-r0dP8I1_HQB7BjOuQgAHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vAuCuJFVqtatv1dQzuHdEQHaH1.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vB2AnLR33Hqy7McabJTYZgHaFt.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vC--3y9etGAFPZdZ6Z1OpAHaJ4.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vC1DWNUBUYvsVGbtHF-nuAHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vDZrYhw3HRgng_fWBjmGqAHaFi.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vEv83DoHnnmvNsMpAgjZKgHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vGhbTc2e427LOSeEHruFLgHaGH.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vPgeUq9ry1QMGNgpl1LEagHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vQryGcY3caJ692E9neA1ZwHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vR9CjSrpLdt_MCsyVhKY4QAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vS7h2mfcV8YNT7xwJltTcAHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vT6pcDuNzdRNiHygWuI9uwHaHa.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vTHXgESFUqpx-1KPo6DORwHaE9.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vUWvN7YZPkW3da27eLnwVwHaFo.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vVhNxoCHEocpJXF5QvriTQHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vWovTQPSWojyZaQPTevVaAAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vZ59C_tM-OmpcAF7TervHAHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vadjFJ8pOeSkz1eRCFteCgHaFc.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vbVcLtl4vYKpqnzuwebqrQHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vkRdW7Fedh--4Q5ITWSyuQHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vlB_1RDuY4G4n0ExDu8RJAHaE6.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vlt7IwhS9Zy78_3S4Gl_ZgHaFp.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-voYmvU-8aA42y8gTp2w5LgHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vucmravYWOuN_B-K-VQWjAHaHa.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vvWp7sUf3E9NJn2pKYntNQHaD4.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-vwx9bSm37ihiVWqQUB3cyQHaEo.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-w-iiqMehb38TTSVRrcxaigHaDt.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-w20jhMtKm7AdsYK2f1vpOgHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-w3czpkComfYE7Lsz4HDy9QHaFb.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-w4COlXBVpPU-b5OfbJyf_AHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-w4uJEjYJxbo3B-SkBMbPGwAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-w722FEhJCFI9pw0rXYLyiAHaFt.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wCITkw6fPpEzkMFY3L-nNQHaGc.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wCeAtviBScM0YZhP_sZmlQHaFb.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wGg38D4wmvMGqF9YMy3lIgHaHD.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wIAoJuFmJeLvkmFAXmlYngHaGD.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wJhu6MT8aVn48WZN5-U_CAHaGX.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wL1OHqiTSW-2rnlPGYlihgHaEe.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wMiAzngvUpDH-ndYlIoVzQHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wOH3Sq9vpbJ4mdAlF3_nTQHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wQ7DsSs8EH-u102_KN_d5QHaDt.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wR_Pn33_qwAKcLERwVJOFQAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wWV0GeHUiO2J4c_mqvkrgQHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wXJ6DO8w_s3eLhbT-E4RIwHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wYAQ5t0n29TRNPZleLxTDgHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wYm0uf6oTmZ28486H2eDZgHaKO.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wZi8rVRIynW2fNAJAb9d3AHaFu.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-w_fYbGPNRENFn2yKEN2BVQHaLH.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wa8-LksmlxT0dUsblXX6_QHaHA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wb4cZTASzAO5PEVt0K4tkAHaFL.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wcejq3dFX7Q2wNuf9-Z3QAHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wdYoc2SpAQc0tDzqLVclvAHaEo.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wf60tdq1lqZb13Kfb7AvzwHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wfRnLbBjlypvU2O067r5wAHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wfYDNpqk2YrBYxwFsXfVGwHaHa.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wg8b02tLIGcazOJAbZ9WhAHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wjBk05GGOFnoWVBlxtjicQHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wjqTfSOilMww4dn4PeEXPAHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wnCzGa2YMCgDSPElspTBAgHaFI.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wrP7oN_ipZ421e82YYCargHaEm.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ws1Psw7Jfmvb0x5GbOJ4hwHaFT.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wsn1eE9Z4Lei3UO9K3D1KQHaFH.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wvC8wQ46CjP8MNNwH5iHTgHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-wxCffksAFW6XW3T_lJfclgHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-x-Ys6Gup0J-aF4fOpILCegHaEH.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-x0Dp-KGt9zIOOGZUMA0fyAHaEb.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-x3jsbWE986Zyz0Qjx2aMUAHaFV.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-x5isiNLWifFz78xdkMvUwgHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-x9E02WEN9UxGcgXj3VblhAHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xAMh8SSTDjhFVOWW3q4ROQHaFc.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xAP1so5BgYcLxRIUhVYUAgHaFW.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xATD-TaiypckbsJ3gjLIGAHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xEIAkajln0z7dhpFFXnCaQHaGc.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xHLTzljPsPyGL6irVNxu4QHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xHXeD7tZI0rEPljQzpDCCAHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xJdvqyKlhb8eqTo603Cy_QAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xJuqSpaD-Dmm7S7eH4KrtQHaE3.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xKYyIS33z6yU98q05sF5yAHaHn.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xKdmqmWDqVjMh77IdE4esgHaE6.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xL0WlnatzXlu5meDmwGBEgEyDM.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xLyXqu4LNuaBobjTRt0cnAHaLJ.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xNIjuk2Vw6U5OeE2ahS_rQHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xNXcnStnAUwknYv6q3SAYgHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xOCABsxqKkUg5eC-rew1XAHaDt.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xSn8zdtlbh6CTVeNKLzh5wHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xU25y2pehtyd7kxR-Y55YAHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xXppqCqAAttfrEER-aFOOAHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-x_19ZG16UzgBUjdOouHrbAHaE6.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-x_5yzPAHxHrgrGGFFDtJRAHaFP.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xc8Cj3JJ7uw5SAmbvXxFLwAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xfkiC8RyM2BN8AmVKTV4gwHaFy.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xkHIglbW_1OCD3pT9MqoCAHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xli3YFm6JvyOuUQRUtVzvQHaG-.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xmVIW3zng__INanL4IA2WwHaKj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xoCKe7GLdJZ05cnkh1JPggHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xq5e35WizCPvhmM2Md3RdAHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xys6DWhLu5kKtRLB3ThrzwHaFc.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xzKxHldb5bZYJCnnBH91twHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xzZzCw8UwEOEf14Tb45O0gHaFg.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-xziVYV8vGTFjF4CzDHuipwHaLH.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-y4IxvJSvX7MqsAlnk49ITgHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yB4QSPjlcdYGQwizOZAJogHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yBv80z117f6vV4EN8e7d4QHaLL.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yEDzihMNoXF-xOUTAU6Q3AHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yHTeNq9R8DDfsXFXfI7w8gHaFc.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yIFOn20fxhRcJ29O9uJx7gHaEo.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yLHtUL4T95AK7x2Va9aZ4QHaGQ.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yLJovM5_nAzGbqDQZ1SEhwHaJo.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yLvvDGYlMAhhXBkTPvA4IQHaFi.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yNOvbu6jPEikpaoU5uaQ1QAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yPnoy1IkDhxesASdsRhxqwAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yUYBYcKSr4yp9UZPqv8v6QHaE3.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yXl5yDIFFDeOErg2lXEitgHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yYkUFqt3-Luv8yTCWGJF5wHaFq.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-y_LhgCj_SFDeUfpT519gXQHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ybqM9IuDWY2tkqM3clTWNQHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ycxyJ5k8La6dDi2GbEwmLQHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ye7thQ5-qCtZxXZJqYwnbwAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ygDZzFQIlEpSCXKwJPoG8QAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ygfPaNnmUlnetNn9zAZMdQHaEo.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yjz3HDAtK0E94baTZOq0vAHaFP.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yka4v1ZUQe3hUWhp6Aq7tQAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ynPgue9MX5T_rLNTIdixTQHaGL.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yo4BhLWnzy03EhF3EMpkFAHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ypvnupPWTKy395NuuNHdBwHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-yqiDUfEUWjYGAFDe2eyHlwHaE6.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ytfyiMBXwQeO9BmVEXQ1rwHaI8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-ywR1iTzpP4Rr083pQ1LmvAHaFz.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-z-1uhOhwztGOqDulrEaKOgHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-z1uhlwHr5D31NRF1hCS_GQHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-z4OZ9Sudx_MmdoZJLDLxuQHaFj.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-z4SqJD-ixyK2xXSMP3oZQAHaE6.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-z6yQWqUVgODwQjlONFGFrAHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-z9Zuh6Td4hQNO0BOP7VPlwHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zBsym6h7uIvfZtE52lwYYAHaJ4.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zEF5uw6Km8yKjLpbi1EK0wHaEK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zEUYFDm5HzhJ7-wwQ84RZAHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zFWF4AQsVuw2a70awHTbXAAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zGQZIl0zO8kIxvK_A6zgTgHaE7.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zM3-CoKympHhLnHTWerTmQAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zSvrkLxfcHGXLXGA0HuAhQHaFY.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zYBdcDlCOtl_jVRthapcBAHaJr.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zYD_2_Leq1OPNGZxVLMlkQHaJh.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zfDq_DKh-s5jdzFKjLuMJAHaFy.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zhJ-pBR-0ryoI4c8Y00XIgHaD3.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zhLz2NNZOh527Bvrz2dlpAHaFw.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zmrCT577lLJ3FGpqKbGFAAHaGl.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zoNeR-sDqoFiOkMJrGWv-gHaG9.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zp2D7FAPeubKw4S1WChEfQHaEo.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zpD7SDCbIqwjYm2A06OybwHaID.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zpZ5t_rN3DA6xByG0o05WwAAAA.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zwWLqRd95U-BjagmhkAgoQHaFK.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zyCc-DDxjCSB5m9DR3uNKQHaE8.jpeg
#   inflating: /content/dataset/raw-img/scoiattolo/OIP-zzy5kEbHuGBWXZ3c-D85aAHaE8.jpeg
#   inflating: /content/dataset/translate.py

# %%
# imports
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import os
from PIL import Image
from collections import Counter

import torch
from torch import optim
import torchvision
from torchvision import models
import torchvision.datasets
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision.utils import make_grid
from torchvision.io import read_image

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix

# %% [markdown]
# # **init resnet model**

# %%
model = models.resnet18(pretrained=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 174MB/s]

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# # **2. Налаштування кількості вихідних класів**

# %% [markdown]
# # **loading data**

# %%
# counting number of images in classes
path = '/content/dataset/raw-img'
classes = os.listdir(path)

class_names = {}
for class_name in classes:
  class_names[class_name] = len(os.listdir(os.path.join(path, class_name)))

class_names
# Out:
# {'gallina': 3098,
#  'scoiattolo': 1862,
#  'pecora': 1820,
#  'mucca': 1866,
#  'gatto': 1668,
#  'ragno': 4821,
#  'farfalla': 2112,
#  'elefante': 1446,
#  'cane': 4863,
#  'cavallo': 2623}

# %%
# loading dataset
data = torchvision.datasets.ImageFolder(root='/content/dataset/raw-img', transform=None)

# %%
# getting classes names
classes = data.classes
num_classes = len(classes)
print(f'data classes: {classes}, number of classes: {num_classes}')
# Out:
# data classes: ['cane', 'cavallo', 'elefante', 'farfalla', 'gallina', 'gatto', 'mucca', 'pecora', 'ragno', 'scoiattolo'], number of classes: 10

# %%
model.fc = nn.Linear(model.fc.in_features, num_classes)

# %%
model.fc
# Out:
# Linear(in_features=512, out_features=10, bias=True)

# %% [markdown]
# # **3. Проведення донавчання моделі**

# %%
layers = ['layer4', 'layer3', 'layer2', 'layer1']

# %%
def unfreeze_layer(model, layer):
    for name, param in model.named_parameters():
        if layer in name:
            param.requires_grad = True

# %%
for param in model.parameters():
    param.requires_grad = False

# unfreezing of layer 4 (first)
for param in model.layer4.parameters():
    param.requires_grad = True

# %%
learning_rate = 1e-4

# %%
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, threshold=0.0001, threshold_mode='abs')

# %%
IMAGE_SIZE = (224, 224)
MEANS = [0.517645001411438, 0.5002366304397583, 0.4124912917613983]
STDS = [0.2544998228549957, 0.2494899481534958, 0.2677474021911621]

# %%
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(IMAGE_SIZE[0]),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=MEANS, std=STDS)
])

# %%
transform_test = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(mean=MEANS, std=STDS)
])

# %%
# transtating classes to english
translate = {"cane": "dog", "cavallo": "horse", "elefante": "elephant", "farfalla": "butterfly", "gallina": "chicken", "gatto": "cat", "mucca": "cow",
             "pecora": "sheep", "ragno": "spider", "scoiattolo": "squirrel"}
classes_eng = [translate[animal] for animal in translate]

# %% [markdown]
# # **dividing dataset to train and test**

# %%
# dividing dataset to train, validation and test
train_size = int(len(data) * 0.7)
test_size = int(len(data) * 0.15)
val_size = int(len(data) - train_size - test_size)

train_data, test_data, valid_data = random_split(dataset=data, lengths=[train_size, test_size, val_size])
print(f'train: {len(train_data):<20} test: {len(test_data):<20} validation: {len(valid_data)}')
# Out:
# train: 18325                test: 3926                 validation: 3928

# %% [markdown]
# ## **adding transformation to datasets**

# %%
class SubsetWithTransform():
    def __init__(self, subset, transform):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, index):
        image, label = self.subset[index]
        if self.transform:
            image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.subset)

# %%
train_data = SubsetWithTransform(train_data, transform=train_transforms)
test_data = SubsetWithTransform(test_data, transform=transform_test)
valid_data = SubsetWithTransform(valid_data, transform=train_transforms)

# %%
train_data.transform, test_data.transform, valid_data.transform
# Out:
# (Compose(
#      RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear, antialias=True)
#      RandomHorizontalFlip(p=0.5)
#      RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#      ColorJitter(brightness=(0.8, 1.2), contrast=(0.8, 1.2), saturation=(0.8, 1.2), hue=None)
#      ToTensor()
#      Normalize(mean=[0.517645001411438, 0.5002366304397583, 0.4124912917613983], std=[0.2544998228549957, 0.2494899481534958, 0.2677474021911621])
#  ),
#  Compose(
#      Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#      ToTensor()
#      Normalize(mean=[0.517645001411438, 0.5002366304397583, 0.4124912917613983], std=[0.2544998228549957, 0.2494899481534958, 0.2677474021911621])
#  ),
#  Compose(
#      RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear, antialias=True)
#      RandomHorizontalFlip(p=0.5)
#      RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#      ColorJitter(brightness=(0.8, 1.2), contrast=(0.8, 1.2), saturation=(0.8, 1.2), hue=None)
#      ToTensor()
#      Normalize(mean=[0.517645001411438, 0.5002366304397583, 0.4124912917613983], std=[0.2544998228549957, 0.2494899481534958, 0.2677474021911621])
#  ))

# %% [markdown]
# ## **creating data loaders**

# %%
num_workers = 2

# %%
batch_size=32
batch_size
# Out:
# 32

# %%
# creating data loader
data_loader = DataLoader(dataset=data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
data_loader

# %%
# creating data loader for test and train data
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
# creating data loader for validation data
valid_loader = DataLoader(dataset=valid_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
loss_function = nn.CrossEntropyLoss()

# %%
number_epochs = 20
number_epochs
# Out:
# 20

# %%
len(valid_data), valid_loader.batch_size
# Out:
# (3928, 32)

# %%
print(f'Model: {model},\n\nLoss function: {loss_function},\n\nOptimizer: {optimizer},\n\nScheduler: {scheduler}')
# Out:
# Model: ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# ),
#
# Loss function: CrossEntropyLoss(),
#
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0
# ),
#
# Scheduler: <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7916a4bff710>

# %%
def evaluate_metrics(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = sum(p == l for p, l in zip(all_preds, all_labels)) / len(all_labels)
    precision = precision_score(all_labels, all_preds, average="macro", zero_division=0)
    recall = recall_score(all_labels, all_preds, average="macro", zero_division=0)
    f1 = f1_score(all_labels, all_preds, average="macro", zero_division=0)

    return accuracy * 100, precision, recall, f1

# %%
train_loss_list = []
val_loss_list = []
train_metrics = {metric: [] for metric in ['accuracy', 'f1_score', 'recall_score', 'precision']}
val_metrics = {metric: [] for metric in ['accuracy', 'f1_score', 'recall_score', 'precision']}

# %%
def train_epoch():
  model.train()
  train_loss = torch.tensor(0.0, device=device)

  for images, labels in train_loader:
      images, labels = images.to(device), labels.to(device)
      optimizer.zero_grad()
      outputs = model(images)
      loss = loss_function(outputs, labels)
      loss.backward()
      optimizer.step()
      train_loss += loss.item()

  train_loss = train_loss.item() / len(train_loader)
  train_loss_list.append(train_loss)

  train_accuracy, train_precision, train_recall, train_f1 = evaluate_metrics(model, train_loader)
  train_metrics['accuracy'].append(train_accuracy)
  train_metrics['f1_score'].append(train_f1)
  train_metrics['recall_score'].append(train_recall)
  train_metrics['precision'].append(train_precision)
  return train_loss, train_accuracy, train_precision, train_recall, train_f1

# %%
def eval_epoch():
  model.eval()
  val_loss = torch.tensor(0.0, device=device)

  with torch.no_grad():
      for images, labels in valid_loader:
          images, labels = images.to(device), labels.to(device)
          outputs = model(images)
          loss = loss_function(outputs, labels)
          val_loss += loss.item()

  val_loss = val_loss.item() / len(valid_loader)
  val_loss_list.append(val_loss)

  val_accuracy, val_precision, val_recall, val_f1 = evaluate_metrics(model, valid_loader)
  val_metrics['accuracy'].append(val_accuracy)
  val_metrics['f1_score'].append(val_f1)
  val_metrics['recall_score'].append(val_recall)
  val_metrics['precision'].append(val_precision)
  return val_loss, val_accuracy, val_precision, val_recall, val_f1

# %%
for epoch in range(number_epochs):

    if epoch == 5:
        unfreeze_layer(model, layers[1])
    elif epoch == 10:
        unfreeze_layer(model, layers[2])
    elif epoch == 15:
        unfreeze_layer(model, layers[-1])

    train_loss, train_accuracy, train_precision, train_recall, train_f1 = train_epoch()
    val_loss, val_accuracy, val_precision, val_recall, val_f1 = eval_epoch()
    scheduler.step(val_loss)

    print(f"Epoch {epoch+1}/{number_epochs}:"
          f"\n\tTrain Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%,"
          f"\n\tTrain Precision: {train_precision:.4f}, Train Recall: {train_recall:.4f}, Train F1-score: {train_f1:.4f}"
          f"\n\tVal Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%,"
          f"\n\tVal Precision: {val_precision:.4f}, Val Recall: {val_recall:.4f}, Val F1-score: {val_f1:.4f}\n")
# Out:
# Epoch 1/20:
# 	Train Loss: 0.5526, Train Accuracy: 89.28%,
# 	Train Precision: 0.8880, Train Recall: 0.8812, Train F1-score: 0.8842
# 	Val Loss: 0.3781, Validation Accuracy: 87.30%,
# 	Val Precision: 0.8661, Val Recall: 0.8615, Val F1-score: 0.8630
#
# Epoch 2/20:
# 	Train Loss: 0.3762, Train Accuracy: 90.75%,
# 	Train Precision: 0.9093, Train Recall: 0.8951, Train F1-score: 0.9014
# 	Val Loss: 0.3462, Validation Accuracy: 88.75%,
# 	Val Precision: 0.8839, Val Recall: 0.8722, Val F1-score: 0.8770
#
# Epoch 3/20:
# 	Train Loss: 0.3384, Train Accuracy: 91.32%,
# 	Train Precision: 0.9126, Train Recall: 0.9022, Train F1-score: 0.9066
# 	Val Loss: 0.3351, Validation Accuracy: 89.66%,
# 	Val Precision: 0.8933, Val Recall: 0.8847, Val F1-score: 0.8878
#
# Epoch 4/20:
# 	Train Loss: 0.3172, Train Accuracy: 92.34%,
# 	Train Precision: 0.9202, Train Recall: 0.9152, Train F1-score: 0.9174
# 	Val Loss: 0.3186, Validation Accuracy: 89.64%,
# 	Val Precision: 0.8912, Val Recall: 0.8877, Val F1-score: 0.8888
#
# Epoch 5/20:
# 	Train Loss: 0.3019, Train Accuracy: 92.56%,
# 	Train Precision: 0.9275, Train Recall: 0.9178, Train F1-score: 0.9223
# 	Val Loss: 0.2979, Validation Accuracy: 89.56%,
# 	Val Precision: 0.8974, Val Recall: 0.8836, Val F1-score: 0.8893
#
# Epoch 6/20:
# 	Train Loss: 0.2796, Train Accuracy: 92.26%,
# 	Train Precision: 0.9244, Train Recall: 0.9132, Train F1-score: 0.9181
# 	Val Loss: 0.2979, Validation Accuracy: 90.20%,
# 	Val Precision: 0.8993, Val Recall: 0.8918, Val F1-score: 0.8941
#
# Epoch 7/20:
# 	Train Loss: 0.2813, Train Accuracy: 93.00%,
# 	Train Precision: 0.9267, Train Recall: 0.9248, Train F1-score: 0.9257
# 	Val Loss: 0.2789, Validation Accuracy: 90.84%,
# 	Val Precision: 0.8991, Val Recall: 0.9025, Val F1-score: 0.9006
#
# Epoch 8/20:
# 	Train Loss: 0.2614, Train Accuracy: 93.40%,
# 	Train Precision: 0.9309, Train Recall: 0.9280, Train F1-score: 0.9293
# 	Val Loss: 0.2697, Validation Accuracy: 90.94%,
# 	Val Precision: 0.8986, Val Recall: 0.9031, Val F1-score: 0.9005
#
# Epoch 9/20:
# 	Train Loss: 0.2548, Train Accuracy: 93.53%,
# 	Train Precision: 0.9320, Train Recall: 0.9317, Train F1-score: 0.9316
# 	Val Loss: 0.2795, Validation Accuracy: 90.55%,
# 	Val Precision: 0.8997, Val Recall: 0.9003, Val F1-score: 0.8997
#
# Epoch 10/20:
# 	Train Loss: 0.2463, Train Accuracy: 93.62%,
# 	Train Precision: 0.9392, Train Recall: 0.9270, Train F1-score: 0.9326
# 	Val Loss: 0.2824, Validation Accuracy: 90.78%,
# 	Val Precision: 0.9069, Val Recall: 0.8973, Val F1-score: 0.9011
#
# Epoch 11/20:
# 	Train Loss: 0.2347, Train Accuracy: 93.81%,
# 	Train Precision: 0.9355, Train Recall: 0.9322, Train F1-score: 0.9337
# 	Val Loss: 0.2898, Validation Accuracy: 91.12%,
# 	Val Precision: 0.9025, Val Recall: 0.9031, Val F1-score: 0.9025
#
# Epoch 12/20:
# 	Train Loss: 0.2333, Train Accuracy: 93.95%,
# 	Train Precision: 0.9391, Train Recall: 0.9332, Train F1-score: 0.9359
# 	Val Loss: 0.2801, Validation Accuracy: 91.17%,
# 	Val Precision: 0.9061, Val Recall: 0.9064, Val F1-score: 0.9059
#
# Epoch 13/20:
# 	Train Loss: 0.2311, Train Accuracy: 93.89%,
# 	Train Precision: 0.9402, Train Recall: 0.9320, Train F1-score: 0.9359
# 	Val Loss: 0.2794, Validation Accuracy: 91.14%,
# 	Val Precision: 0.9084, Val Recall: 0.9009, Val F1-score: 0.9043
#
# Epoch 14/20:
# 	Train Loss: 0.2221, Train Accuracy: 94.24%,
# 	Train Precision: 0.9404, Train Recall: 0.9383, Train F1-score: 0.9391
# 	Val Loss: 0.2791, Validation Accuracy: 92.16%,
# 	Val Precision: 0.9169, Val Recall: 0.9145, Val F1-score: 0.9153
#
# Epoch 15/20:
# 	Train Loss: 0.2279, Train Accuracy: 94.19%,
# 	Train Precision: 0.9418, Train Recall: 0.9362, Train F1-score: 0.9387
# 	Val Loss: 0.2811, Validation Accuracy: 90.50%,
# 	Val Precision: 0.8972, Val Recall: 0.8940, Val F1-score: 0.8950
#
# Epoch 16/20:
# 	Train Loss: 0.2170, Train Accuracy: 94.49%,
# 	Train Precision: 0.9428, Train Recall: 0.9386, Train F1-score: 0.9405
# 	Val Loss: 0.2711, Validation Accuracy: 90.91%,
# 	Val Precision: 0.9024, Val Recall: 0.8996, Val F1-score: 0.9002
#
# Epoch 17/20:
# 	Train Loss: 0.2159, Train Accuracy: 94.48%,
# 	Train Precision: 0.9439, Train Recall: 0.9375, Train F1-score: 0.9405
# 	Val Loss: 0.2802, Validation Accuracy: 90.78%,
# 	Val Precision: 0.9027, Val Recall: 0.9016, Val F1-score: 0.9014
#
# Epoch 18/20:
# 	Train Loss: 0.2103, Train Accuracy: 94.70%,
# 	Train Precision: 0.9468, Train Recall: 0.9401, Train F1-score: 0.9433
# 	Val Loss: 0.2623, Validation Accuracy: 91.04%,
# 	Val Precision: 0.9108, Val Recall: 0.9024, Val F1-score: 0.9059
#
# Epoch 19/20:
# 	Train Loss: 0.2043, Train Accuracy: 94.47%,
# 	Train Precision: 0.9458, Train Recall: 0.9384, Train F1-score: 0.9419
# 	Val Loss: 0.2635, Validation Accuracy: 90.94%,
# 	Val Precision: 0.9067, Val Recall: 0.8992, Val F1-score: 0.9026
#
# Epoch 20/20:
# 	Train Loss: 0.1942, Train Accuracy: 94.53%,
# 	Train Precision: 0.9433, Train Recall: 0.9400, Train F1-score: 0.9415
# 	Val Loss: 0.2649, Validation Accuracy: 91.09%,
# 	Val Precision: 0.9063, Val Recall: 0.9028, Val F1-score: 0.9043

# %%
fig, ax = plt.subplots(3, 2, figsize=(10, 10))

ax[0,0].plot(train_metrics['accuracy'], color='g')
ax[0,0].set_title('Train Accuracy')

ax[0,1].plot(train_loss_list, color='r')
ax[0,1].set_title('Train Losses')

ax[1,0].plot(train_metrics['f1_score'], color='g')
ax[1,0].set_title('Train F1 Score')

ax[1,1].plot(train_metrics['precision'], color='g')
ax[1,1].set_title('Train Precision')

ax[2,0].plot(train_metrics['recall_score'], color='g')
ax[2,0].set_title('Train Recall Score')
# Out:
# Text(0.5, 1.0, 'Train Recall Score')

# %%
fig, ax = plt.subplots(3, 2, figsize=(10, 10))

ax[0,0].plot(val_metrics['accuracy'], color='g')
ax[0,0].set_title('Validation Accuracy')

ax[0,1].plot(val_loss_list, color='r')
ax[0,1].set_title('Validation Losses')

ax[1,0].plot(val_metrics['f1_score'], color='g')
ax[1,0].set_title('Validation F1 Score')

ax[1,1].plot(val_metrics['precision'], color='g')
ax[1,1].set_title('Validation Precision')

ax[2,0].plot(val_metrics['recall_score'], color='g')
ax[2,0].set_title('Validation Recall Score')
# Out:
# Text(0.5, 1.0, 'Validation Recall Score')

# %%
all_labels = []
all_preds = []
all_images = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)

        all_labels.append(labels.cpu().numpy())
        all_preds.append(predicted.cpu().numpy())
        all_images.append(images.cpu().numpy())

all_labels = np.concatenate(all_labels)
all_preds = np.concatenate(all_preds)
all_images = np.concatenate(all_images)

# %%
incorrect_indices = np.where(all_labels != all_preds)[0]
incorrect_images = all_images[incorrect_indices]
incorrect_labels = all_labels[incorrect_indices]
incorrect_preds = all_preds[incorrect_indices]

# %%
len(incorrect_indices), len(all_labels), len(incorrect_labels) / len(all_labels) * 100
# Out:
# (150, 3926, 3.8206826286296485)

# %%
fig, axes = plt.subplots(3, 3, figsize=(5, 7))
model.eval()

images, labels = next(iter(test_loader))
images, labels = images.to(device), labels.to(device)
outputs = model(images)
_, predicted = outputs.max(1)

for i, ax in enumerate(axes.flat):
    img = images[i]
    img = img / 2 + 0.5
    img = img.cpu().numpy().transpose((1, 2, 0))
    ax.imshow(img)
    ax.set_title(f'Real: {classes_eng[labels[i].item()]}\nPred: {classes_eng[predicted[i].item()]}')
    ax.axis('off')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5898092].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50251865..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.38463104..1.5824858].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.48680025..1.5531927].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50157607..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.44764483..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49465942..1.5824858].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.4858518].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5015701].

# %%
fig, axes = plt.subplots(5, 5, figsize=(10, 13))

for i, ax in enumerate(axes.flat):
    if i < len(incorrect_images):
        img = incorrect_images[i]
        img = img.transpose((1, 2, 0))
        img = (img * 0.5) + 0.5

        ax.imshow(img)
        ax.set_title(f'Real: {classes_eng[incorrect_labels[i]]}\nPred: {classes_eng[incorrect_preds[i]]}')
        ax.axis('off')
    else:
        ax.axis('off')

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4707582..1.5015701].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.4476529].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.36105353..1.4168351].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.37060022..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50928056..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49387163..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41682696..1.304202].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50251865..1.5751626].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50157607..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5312232].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49387163..1.5898092].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49387163..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.48680025..1.5385463].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.4286973].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50157607..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50928056..1.5015701].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.5971323].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51698494..1.3629038].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50928056..1.493711].

# %%
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes_eng, yticklabels=classes_eng)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Найкраще передбачення були зроблені на класах "Павук" та "Собака", можливо це зумовлено найбільшою часткою зображень даних класів в датасеті. Отже точність передбачень може залежати від кількості екземплярів представників певного класу.

# %%
print(classification_report(all_labels, all_preds, target_names=classes_eng))
# Out:
#               precision    recall  f1-score   support
#
#          dog       0.97      0.96      0.97       704
#        horse       0.96      0.95      0.95       365
#     elephant       0.96      0.96      0.96       227
#    butterfly       0.93      0.99      0.96       321
#      chicken       0.98      0.96      0.97       489
#          cat       0.92      0.96      0.94       254
#          cow       0.96      0.93      0.94       285
#        sheep       0.92      0.97      0.95       291
#       spider       0.99      0.97      0.98       743
#     squirrel       0.98      0.96      0.97       247
#
#     accuracy                           0.96      3926
#    macro avg       0.96      0.96      0.96      3926
# weighted avg       0.96      0.96      0.96      3926

# %% [markdown]
# Найкращі f1 score у класу 'spider' (0.98)
#
# Найгірші - у 'cow' (0.94)

# %%
torch.save(model.state_dict(), 'model_best.pth')
